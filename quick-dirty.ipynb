# %% [markdown]
# # 1. Reverse engineer data
#
# dimensionality

# %%
import pickle

fid = open('data/w2v_MSRVTT.pickle', 'rb')
x = pickle.load(fid)

# %%
for i in x.iteritems():
    print(i)
    break
# Out:
# (u'video8831', [array([[ 0.09423828, -0.02282715,  0.05224609, ..., -0.046875  ,
#          0.16113281, -0.19921875],
#        [-0.09667969, -0.02636719,  0.09033203, ..., -0.01965332,
#          0.21386719,  0.13671875],
#        [ 0.17871094,  0.09130859, -0.00165558, ...,  0.125     ,
#          0.08056641,  0.01672363],
#        ...,
#        [ 0.22558594,  0.15039062, -0.10595703, ..., -0.20507812,
#         -0.03686523,  0.0456543 ],
#        [ 0.0703125 ,  0.08691406,  0.08789062, ..., -0.04760742,
#          0.01446533, -0.0625    ],
#        [ 0.11132812,  0.00286865, -0.08349609, ...,  0.07226562,
#          0.05981445, -0.03613281]], dtype=float32), array([[-0.02197266,  0.01519775, -0.02990723, ...,  0.07226562,
#          0.03112793,  0.00311279],
#        [ 0.26367188, -0.01916504,  0.02893066, ..., -0.06689453,
#          0.20703125, -0.13867188],
#        [-0.09667969, -0.02636719,  0.09033203, ..., -0.01965332,
#          0.21386719,  0.13671875],
# ...

# %%
j = i[1]
print type(j)
print j[0].shape
print j[1].shape
# Out:
# <type 'list'>
# (7, 300)
# (6, 300)
